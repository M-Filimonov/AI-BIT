# %%
# !pip install apify-client aiohttp asyncio pandas python-dotenv tqdm beautifulsoup4 pyarrow

# %%
#!pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in c:\users\fmikh\appdata\local\programs\python\python312\lib\site-packages (1.6.0)

# %%
import os
import asyncio
import logging
from logging.handlers import RotatingFileHandler

import nest_asyncio
nest_asyncio.apply()

import pandas as pd
from apify_client import ApifyClient
from bs4 import BeautifulSoup
from tqdm import tqdm


# -----------------------------
# 1. API Token
# -----------------------------
API_TOKEN = "apify_api_oyTJYoRZLi31jxi2aX9fhqTS5xhMdv0Crsz9"
ACTOR_ID = "pocesar/stepstone-scraper"   # ← бесплатный рабочий актор


# -----------------------------
# 2. Search terms
# -----------------------------
SEARCH_TERMS = [
    "Business Transformation Analyst",
    "Digital Process Analyst",
    "AI Project Manager",
    "AI Product Manager",
    "AI Governance Analyst",
    "AI Automation Specialist",
    "Prompt Engineer",
    "Junior Automation Specialist",
    "Prozessmanager/in",
    "KI-Manager/in",
    "Prozessmanager/in – RPA",
    "KI-Prompter",
    "Prozessmanager/in – RPA (Junior)"
]

FIELDS = [
    "title",
    "company",
    "location",
    "employmentType",
    "seniority",
    "url",
    "skills",
    "languages",
    "education",
    "experience",
    "description"
]


# -----------------------------
# 3. Logging
# -----------------------------
logger = logging.getLogger("stepstone_scraper")
logger.setLevel(logging.INFO)

handler = RotatingFileHandler(
    "scraper.log",
    maxBytes=2_000_000,
    backupCount=3,
    encoding="utf-8"
)
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)

logger.handlers.clear()
logger.addHandler(handler)


# -----------------------------
# 4. HTML cleaner
# -----------------------------
def clean_html(text):
    if not text:
        return None
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text(separator=" ", strip=True)


# -----------------------------
# 5. Async actor runner
# -----------------------------
client = ApifyClient(API_TOKEN)

async def run_actor_async(search_term: str):
    logger.info(f"Запуск скрапинга для: {search_term}")

    run = client.actor(ACTOR_ID).call(
        run_input={
            "query": search_term,      # ← корректный параметр
            "location": "Germany",
            "maxItems": 150
        }
    )

    dataset_id = run["defaultDatasetId"]
    dataset = client.dataset(dataset_id)
    items = dataset.list_items().items

    logger.info(f"Получено {len(items)} вакансий для: {search_term}")
    return search_term, items


# -----------------------------
# 6. Async scraping
# -----------------------------
async def scrape_all_async():
    tasks = [run_actor_async(term) for term in SEARCH_TERMS]
    results = []

    for coro in tqdm(asyncio.as_completed(tasks), total=len(tasks), desc="Scraping Stepstone"):
        search_term, items = await coro

        for job in items:
            row = {field: job.get(field) for field in FIELDS}
            row["description_clean"] = clean_html(job.get("description"))
            row["search_term"] = search_term
            results.append(row)

    return pd.DataFrame(results)


# -----------------------------
# 7. Save results
# -----------------------------
def save_results(df):
    df.to_csv("results.csv", index=False, encoding="utf-8")
    df.to_parquet("results.parquet", index=False)
    logger.info(f"Сохранено {len(df)} строк")


# -----------------------------
# 8. Entry point
# -----------------------------
if __name__ == "__main__":
    logger.info("Старт асинхронного скрапинга Stepstone")

    df = asyncio.run(scrape_all_async())

    print(df.head())
    print(f"Всего строк: {len(df)}")

    save_results(df)

    logger.info("Готово!")
# Out:
# Scraping Stepstone:   0%|                                                                       | 0/13 [00:02<?, ?it/s]
# C:\Users\fmikh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py:78: RuntimeWarning: coroutine 'scrape_all_async' was never awaited
#   for group in groupby(strings, lambda s: s[0] == first[0])) \
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\fmikh\AppData\Local\Programs\Python\Python312\Lib\site-packages\pygments\regexopt.py:78: RuntimeWarning: coroutine 'run_actor_async' was never awaited
#   for group in groupby(strings, lambda s: s[0] == first[0])) \
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# ApifyApiError                             Traceback (most recent call last)
# Cell In[6], line 143
#     140 if __name__ == "__main__":
#     141     logger.info("Старт асинхронного скрапинга Stepstone")
# --> 143     df = asyncio.run(scrape_all_async())
#     145     print(df.head())
#     146     print(f"Всего строк: {len(df)}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# Cell In[6], line 117, in scrape_all_async()
#     114 results = []
#     116 for coro in tqdm(asyncio.as_completed(tasks), total=len(tasks), desc="Scraping Stepstone"):
# --> 117     search_term, items = await coro
#     119     for job in items:
#     120         row = {field: job.get(field) for field in FIELDS}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\tasks.py:631, in as_completed.<locals>._wait_for_one()
#     628 if f is None:
#     629     # Dummy value from _on_timeout().
#     630     raise exceptions.TimeoutError
# --> 631 return f.result()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\asyncio\tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# Cell In[6], line 93, in run_actor_async(search_term)
#      90 async def run_actor_async(search_term: str):
#      91     logger.info(f"Запуск скрапинга для: {search_term}")
# ---> 93     run = client.actor(ACTOR_ID).call(
#      94         run_input={
#      95             "search": search_term,
#      96             "location": "Germany",
#      97             "maxItems": 150
#      98         }
#      99     )
#     101     dataset_id = run["defaultDatasetId"]
#     102     dataset = client.dataset(dataset_id)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\apify_client\_logging.py:86, in _injects_client_details_to_log_context.<locals>.wrapper(resource_client, *args, **kwargs)
#      83 log_context.client_method.set(fun.__qualname__)
#      84 log_context.resource_id.set(resource_client.resource_id)
# ---> 86 return fun(resource_client, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\apify_client\clients\resource_clients\actor.py:341, in ActorClient.call(self, run_input, content_type, build, max_items, max_total_charge_usd, restart_on_error, memory_mbytes, timeout_secs, webhooks, force_permission_level, wait_secs, logger)
#     290 def call(
#     291     self,
#     292     *,
#    (...)
#     304     logger: Logger | None | Literal['default'] = 'default',
#     305 ) -> dict | None:
#     306     """Start the Actor and wait for it to finish before returning the Run object.
#     307
#     308     It waits indefinitely, unless the wait_secs argument is provided.
#    (...)
#     339         The run object.
#     340     """
# --> 341     started_run = self.start(
#     342         run_input=run_input,
#     343         content_type=content_type,
#     344         build=build,
#     345         max_items=max_items,
#     346         max_total_charge_usd=max_total_charge_usd,
#     347         restart_on_error=restart_on_error,
#     348         memory_mbytes=memory_mbytes,
#     349         timeout_secs=timeout_secs,
#     350         webhooks=webhooks,
#     351         force_permission_level=force_permission_level,
#     352     )
#     353     if not logger:
#     354         return self.root_client.run(started_run['id']).wait_for_finish(wait_secs=wait_secs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\apify_client\_logging.py:86, in _injects_client_details_to_log_context.<locals>.wrapper(resource_client, *args, **kwargs)
#      83 log_context.client_method.set(fun.__qualname__)
#      84 log_context.resource_id.set(resource_client.resource_id)
# ---> 86 return fun(resource_client, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\apify_client\clients\resource_clients\actor.py:280, in ActorClient.start(self, run_input, content_type, build, max_items, max_total_charge_usd, restart_on_error, memory_mbytes, timeout_secs, force_permission_level, wait_for_finish, webhooks)
#     266 run_input, content_type = encode_key_value_store_record_value(run_input, content_type)
#     268 request_params = self._params(
#     269     build=build,
#     270     maxItems=max_items,
#    (...)
#     277     webhooks=encode_webhook_list_to_base64(webhooks) if webhooks is not None else None,
#     278 )
# --> 280 response = self.http_client.call(
#     281     url=self._url('runs'),
#     282     method='POST',
#     283     headers={'content-type': content_type},
#     284     data=run_input,
#     285     params=request_params,
#     286 )
#     288 return parse_date_fields(pluck_data(response.json()))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\apify_client\_http_client.py:210, in HTTPClient.call(self, method, url, headers, params, data, json, stream, timeout_secs)
#     207     response.read()
#     208     raise ApifyApiError(response, attempt, method=method)
# --> 210 return retry_with_exp_backoff(
#     211     _make_request,
#     212     max_retries=self.max_retries,
#     213     backoff_base_millis=self.min_delay_between_retries_millis,
#     214     backoff_factor=DEFAULT_BACKOFF_EXPONENTIAL_FACTOR,
#     215     random_factor=DEFAULT_BACKOFF_RANDOM_FACTOR,
#     216 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\apify_client\_utils.py:168, in retry_with_exp_backoff(func, max_retries, backoff_base_millis, backoff_factor, random_factor)
#     166 for attempt in range(1, max_retries + 1):
#     167     try:
# --> 168         return func(stop_retrying, attempt)
#     169     except Exception:
#     170         if not swallow:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\apify_client\_http_client.py:208, in HTTPClient.call.<locals>._make_request(stop_retrying, attempt)
#     206 # Read the response in case it is a stream, so we can raise the error properly
#     207 response.read()
# --> 208 raise ApifyApiError(response, attempt, method=method)
#
# ApifyApiError: Actor with this name was not found
